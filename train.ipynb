# %%
import pickle
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
df= pd.read_csv('C:\\Users\\DELL\\coding\\Machine Learning Projects\\02_Calorie_Burn_Prediction\\data\\calories.csv')

# %%
df
# Out:
#         User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0      14733363    male   68   190.0    94.0      29.0       105.0       40.8
# 1      14861698  female   20   166.0    60.0      14.0        94.0       40.3
# 2      11179863    male   69   179.0    79.0       5.0        88.0       38.7
# 3      16180408  female   34   179.0    71.0      13.0       100.0       40.5
# 4      17771927  female   27   154.0    58.0      10.0        81.0       39.8
# ...         ...     ...  ...     ...     ...       ...         ...        ...
# 14995  15644082  female   20   193.0    86.0      11.0        92.0       40.4
# 14996  17212577  female   27   165.0    65.0       6.0        85.0       39.2
# 14997  17271188  female   43   159.0    58.0      16.0        90.0       40.1
# 14998  18643037    male   78   193.0    97.0       2.0        84.0       38.3
# 14999  11751526    male   63   173.0    79.0      18.0        92.0       40.5
#
#        Calories
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   User_ID     15000 non-null  int64
#  1   Gender      15000 non-null  object
#  2   Age         15000 non-null  int64
#  3   Height      15000 non-null  float64
#  4   Weight      15000 non-null  float64
#  5   Duration    15000 non-null  float64
#  6   Heart_Rate  15000 non-null  float64
#  7   Body_Temp   15000 non-null  float64
#  8   Calories    15000 non-null  float64
# dtypes: float64(6), int64(2), object(1)
# memory usage: 1.0+ MB

# %%
df.describe()
# Out:
#             User_ID           Age        Height        Weight      Duration  \
# count  1.500000e+04  15000.000000  15000.000000  15000.000000  15000.000000
# mean   1.497736e+07     42.789800    174.465133     74.966867     15.530600
# std    2.872851e+06     16.980264     14.258114     15.035657      8.319203
# min    1.000116e+07     20.000000    123.000000     36.000000      1.000000
# 25%    1.247419e+07     28.000000    164.000000     63.000000      8.000000
# 50%    1.499728e+07     39.000000    175.000000     74.000000     16.000000
# 75%    1.744928e+07     56.000000    185.000000     87.000000     23.000000
# max    1.999965e+07     79.000000    222.000000    132.000000     30.000000
#
#          Heart_Rate     Body_Temp      Calories
# count  15000.000000  15000.000000  15000.000000
# mean      95.518533     40.025453     89.539533
# std        9.583328      0.779230     62.456978
# min       67.000000     37.100000      1.000000
# ...

# %%
df.plot(kind='box', subplots=True, layout=(4, 2), figsize=(14, 10))
plt.tight_layout()
plt.show()

# %%
df.skew(numeric_only=True)
## normal distributed data
# Out:
# User_ID       0.004788
# Age           0.473383
# Height       -0.006190
# Weight        0.226725
# Duration      0.004751
# Heart_Rate   -0.010704
# Body_Temp    -0.994382
# Calories      0.505371
# dtype: float64

# %%
for col in df.select_dtypes(include='number').columns:
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    iqr = q3 - q1
    lower = q1 - 1.5 * iqr
    upper = q3 + 1.5 * iqr
    df[col] = df[col].clip(lower, upper)

# %%
## no outlier at this time 
df.plot(kind='box', subplots=True, layout=(4, 2), figsize=(14, 10))
plt.tight_layout()
plt.show()

# %%
X = df.iloc[:,1:8]
Y = df.iloc[:,-1]

# %%
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
trf1 = ColumnTransformer([
    ('ohe_gender',OneHotEncoder(sparse_output=False,handle_unknown='ignore'),[0]),
    ('scale',MinMaxScaler(),slice(1,7))
],remainder='passthrough')

# %%
trf2 = LinearRegression()

# %%
pipe = Pipeline([
    ('trf1',trf1),
    ('trf2',trf2)
])

# %%
pipe.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('trf1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe_gender',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   [0]),
#                                                  ('scale', MinMaxScaler(),
#                                                   slice(1, 7, None))])),
#                 ('trf2', LinearRegression())])

# %%
y_pred = pipe.predict(x_test)

# %%
print("R2:", r2_score(y_test, y_pred))
print("MAE:", mean_absolute_error(y_test, y_pred))
print("MSE:", mean_squared_error(y_test, y_pred))
# Out:
# R2: 0.9672955358809852
# MAE: 8.447625844193022
# MSE: 131.97736338041332

# %%
pickle.dump(pipe, open('model.pkl', 'wb'))

# %%
input_data = pd.DataFrame({
    'Gender': ['male'],
    'Age': [68],
    'Height': [190],
    'Weight': [94],
    'Duration': [29],
    'Heart_Rate': [105],
    'Body_Temp': [40.8]
})

prediction = pipe.predict(input_data)

print("Predicted Calories:", prediction[0])
# Out:
# Predicted Calories: 199.38812209615844

# %% [markdown]
# Checking Asumptions of Linear Regression

# %%
## 1.Multicollinearity
from statsmodels.stats.outliers_influence import variance_inflation_factor
import pandas as pd

numeric_data = x_train.select_dtypes(include='number')

vif = pd.DataFrame()
vif['Feature'] = numeric_data.columns
vif['VIF'] = [
    variance_inflation_factor(numeric_data.values, i)
    for i in range(numeric_data.shape[1])
]

print(vif)
# Out:
#       Feature          VIF
# 0         Age     7.967011
# 1      Height  1924.616761
# 2      Weight   334.535006
# 3    Duration    13.931633
# 4  Heart_Rate   363.010391
# 5   Body_Temp  1083.910337

# %%
## multicollinearity
numeric_data = x_train.select_dtypes(include='number')
plt.figure(figsize=(10, 7))
sns.heatmap(numeric_data.corr(), annot=True, cmap='coolwarm')
plt.show()

# %%
## Normality of residual
residual = y_test-y_pred
sns.kdeplot(residual)
# Out:
# <Axes: xlabel='Calories', ylabel='Density'>

# %%
## Homoscedasticity
sns.scatterplot(x=residual,y=y_pred)
# Out:
# <Axes: xlabel='Calories'>

# %%
## AutoCo-relation
plt.plot(residual)
